# %% [markdown]
# ## Python Dealership Scraping Tutorial Part 2: Honda Motor Company
#
# Hello! In this tutorial we will use Python to retrieve dealership data from the [Honda North America](https://www.honda.com/) website!
#
# What you'll need for this part of the tutorial (and all other parts):
# * Python3.3 or later
# * Jupyter Notebooks installed
# * A basic understanding of how websites retrieve and load content to users (or a willingness to learn!)
# * Patience to experiment!
#
# Because individual websites store, retrieve and load data (and by extension, content) to users in vastly different ways, this tutorial is not all-encompassing. What I mean is: While the rough methodology and experimental/scientific method outlined here will work for any site you come across, the code you will have to write to retrieve the data will be different.
#
# Depending on the site administration, you might sometimes get lucky. For instance, Chrsyler, Dodge, Jeep and Ram all use the same back-end [REST API](https://restfulapi.net/) for their United States dealer services. The only difference is the endpoint of the URL you'll want to make your requests to changes depending on whether you want Chrysler, Dodge, Jeep or Ram dealer results.
#
# In most cases, though, you'll find you're repeating the same experimental steps on every site you want to scrape. There will be some similarities that can be generalized, bits of code that can be made into functions and so on, but you'll always want to start with a fresh Jupyter Notebook to get yourself started (in my opinion).
#
# ### A Skippable Tangent: Why Jupyter?
#
# You can skip this section to get right to the "good" stuff if you want. But I'd like to just say I think Jupyter Notebooks, for all their shortcomings as a proper IDE, are the best tool to use for jobs like this.
#
# The rapid experimentation and manipulation of objects (lists, dictionaries, etc.) that you can achieve in a Jupyter Notebook is unrivaled. The interactive nature of them provides a great environment to serve as your scratchpad from which you can copy and paste your "solution" into the IDE of your choice.
#
# There are some things an IDE like PyCharm will do you for: parameter previewing, underlining errors, proper debugging, and so on are just a few to name. But for just getting started, especially if this is your first time writing Python code, Jupyter is tough to beat.
#
# ### Loading Libraries
#
# Okay! Let's load in our libraries. For this I'll be using:
#
# * json : the built-in Python JSON parsing/outputting library
# * requests : the best Python library for interacting with websites/APIs with [HTTP methods](https://www.w3schools.com/tags/ref_httpmethods.asp) (we'll use GET and POST exclusively)
# * mbtools : a custom-made module that has a bunch of useful functions for web scraping
#
# Unfortunately, the name of the author of mbtools has been lost to time. So I can't give them credit in this Notebook for their work.
#
# Notice how I'm importing `mbtools` from a different directory, `lib`, compared to the one I'm in, `scrape_unsecured_js_file`, so the import is structured like:
#
# ```python
# import utils.mbtools as mbtools
# ```
#
# This is possible because of the first code block below. What this does is it adds the `lib` directory that contains the `scraping_utils.py` and `mbtools.py` files to the PATH.

# %%
import sys

sys.path.insert(0, '../lib')

# %% [markdown]
# Now this works as you'd expect since this file can "see" the `lib` directory, even though it's in the `scrape_unsecured_js_file` directory.

# %%
import json
import requests
import mbtools
from geopy import distance
from scraping_utils import show_obj_head as show_obj_head
from scraping_utils import equivalence_checker as equivalence_checker
from scraping_utils import clean_list_of_dicts
import pprint # For pretty printing JSON-like objects

# %% [markdown]
# Keep this in mind as you're moving custom module and utility files around: The project structure is very important and you'll spend a ton of time fixing path issues, relative import issues, etc. if you're not carful.
#
# If you'd like to see the `show_obj_head` and `equivalence_checker` code separately, take a look at the `scraping_utils.py` file located in the `lib` directory. This is where these helper functions are stored.

# %% [markdown]
# ### Let's Dive Right In
#
# I'm not going to repeat a bunch of text and movie references here, if you're interested in seeing the proper introduction to this section I'd advise you to revisit Part One of this tutorial.
#
# Instead, let's just cut to the chase and get rolling. You know the drill, navigate to the dealership search functionality on the Honda website and start playing with the website. If you're having trouble finding it or are not feeling like searching, [here you go!](https://automobiles.honda.com/tools/dealership-locator)
#
# Same deal as Part One: We want to manipulate the site into showing us how it makes requests to a database, API, .js file, etc. to retrieve information. So, let's do that.
#
# Here's what the initial site looks like:
# INSERT SOMETHING HERE FOR AN IMAGE OF THE INITIAL SITE
#
#
# And some things to notice right away that we might be able to take advantage of, before even opening up the Inspect Console:
# * You can search by ZIP
# * You can search by City, State combination
# * You can search by name
# <br>
#
# So we'll have a couple different ways we can attack this site. The intriguing one is the name: Depending on the site security, an old trick we could use would be to send an "empty search" on name and see what we return. Depending on the security and how the back-end is setup, this might return everything or nothing. Definitely worth a try though!
#
# Anyway, let's open up the Inspect Console (`CTRL` + `SHIFT` + `I` if you've forgotten) and start playing!
#
# INSERT SOMETHING HERE TRYING TO DO THE NAME, CITY AND STATE, AND ZIP
#
# It seems like searching on ZIP is the easiest, since that's just one value we have to feed the API instead of two (in the case of City and State). So, let's attack that route and see if we can do one of two things (or a combination of them):
#
# 1. Send requests to a random ZIP and return a sufficiently-larger number of dealers from it
# 2. Send requests to a sufficiently-large number of ZIPs and return only a few dealers from each
#
# The first is easier, but less-likely to be supported by the site. Most of these OEM sites limit you either on the search radius around a ZIP or limit you on the number of results that can be returned from a single request. It's likely we'll need to try the second option, but we'll explore both.

# %%
base_url = 'https://automobiles.honda.com/platform/api/v1/dealer?'

params = \
{
'productDivisionCode': 'A',
'excludeServiceCenters': 'true',
'zip': '48371',
'maxResults': '100'
}
qs_params = json.dumps(params, separators=('&', '='))[1:-1].replace('\"', '')
print(len(requests.get(url=base_url+qs_params).json()['Dealers']))

params = \
{
'productDivisionCode': 'A',
'excludeServiceCenters': 'true',
'zip': '48371',
'maxResults': '500'
}
qs_params = json.dumps(params, separators=('&', '='))[1:-1].replace('\"', '')
print(len(requests.get(url=base_url+qs_params).json()['Dealers']))
# Out:
# 100
# 124

# %%
response = requests.get(url=base_url+qs_params).json()
dealers = response['Dealers']

# %%
# TODO: COME UP WITH NUMPY ALGORITHM TO DO THIS FASTER
zdb_0 = clean_list_of_dicts(original_file_path='../data/input/zdb.txt', 
                            new_file_path='../data/input/geo_data.json',
                            str_fields=['city', 'state', 'zip'],
                            float_fields=['lat', 'lon'])

zdb_1 = zdb_0[0:1]
for item in zdb_0:
    add_item = True
    for coord in zdb_1:
        p0 = float(item['lat']),float(item['lon'])
        p1 = float(coord['lat']),float(coord['lon'])
        d = distance.distance(p0,p1)
        if d.miles < 100:
            add_item = False
    if add_item == True:
        zdb_1.append(item)
zdb = zdb_1

# %%
results_list = []
id_list = []
locations = []

for coord in zdb:
    new = []
    print('Finding Honda dealers near ' + coord['zip'] + '...')
    
    params['zip'] = coord['zip']
    
    qs_params = json.dumps(params, separators=('&', '='))[1:-1].replace('\"', '')
    response = requests.get(url=base_url+qs_params)
    results = response.json()['Dealers']
    
    for res in results:
        site_id = res['DealerNumber']
        
        if site_id not in id_list:
            id_list.append(site_id)
            results_list.append(res)
            new.append(res)
            
    mbtools.print_count(results,new,results_list)
# Out:
# Finding Honda dealers near 01002...
# Scraped: 168
# New: 168
# Total: 168
#
# Finding Honda dealers near 02360...
# Scraped: 134
# New: 1
# Total: 169
#
# Finding Honda dealers near 03561...
# Scraped: 93
# New: 1
# Total: 170
#
# Finding Honda dealers near 04330...
# Scraped: 68
# New: 0
# Total: 170
#
# Finding Honda dealers near 04462...
# Scraped: 22
# New: 0
# Total: 170
#
# Finding Honda dealers near 04743...
# Scraped: 5
# New: 0
# Total: 170
#
# Finding Honda dealers near 06820...
# Scraped: 203
# New: 38
# Total: 208
#
# Finding Honda dealers near 08002...
# Scraped: 197
# New: 26
# Total: 234
#
# Finding Honda dealers near 12043...
# Scraped: 186
# New: 7
# Total: 241
#
# Finding Honda dealers near 12935...
# Scraped: 81
# New: 0
# Total: 241
#
# Finding Honda dealers near 13021...
# Scraped: 167
# New: 12
# Total: 253
#
# Finding Honda dealers near 14006...
# Scraped: 104
# New: 45
# Total: 298
#
# Finding Honda dealers near 15001...
# Scraped: 164
# New: 38
# Total: 336
#
# Finding Honda dealers near 15522...
# Scraped: 200
# New: 3
# Total: 339
#
# Finding Honda dealers near 17752...
# Scraped: 216
# New: 0
# Total: 339
#
# Finding Honda dealers near 20601...
# Scraped: 183
# New: 13
# Total: 352
#
# Finding Honda dealers near 22801...
# Scraped: 168
# New: 18
# Total: 370
#
# Finding Honda dealers near 23320...
# Scraped: 112
# New: 5
# Total: 375
#
# Finding Honda dealers near 23927...
# Scraped: 120
# New: 16
# Total: 391
#
# Finding Honda dealers near 24073...
# Scraped: 141
# New: 9
# Total: 400
#
# Finding Honda dealers near 24219...
# Scraped: 126
# New: 38
# Total: 438
#
# Finding Honda dealers near 25143...
# Scraped: 148
# New: 5
# Total: 443
#
# Finding Honda dealers near 28001...
# Scraped: 100
# New: 8
# Total: 451
#
# Finding Honda dealers near 28328...
# Scraped: 82
# New: 0
# Total: 451
#
# Finding Honda dealers near 28734...
# Scraped: 111
# New: 17
# Total: 468
#
# Finding Honda dealers near 29003...
# Scraped: 97
# New: 12
# Total: 480
#
# Finding Honda dealers near 29585...
# Scraped: 65
# New: 0
# Total: 480
#
# Finding Honda dealers near 30009...
# Scraped: 97
# New: 7
# Total: 487
#
# Finding Honda dealers near 30474...
# Scraped: 87
# New: 8
# Total: 495
#
# Finding Honda dealers near 31548...
# Scraped: 66
# New: 21
# Total: 516
#
# Finding Honda dealers near 31643...
# Scraped: 76
# New: 2
# Total: 518
#
# Finding Honda dealers near 32114...
# Scraped: 63
# New: 18
# Total: 536
#
# Finding Honda dealers near 32405...
# Scraped: 49
# New: 6
# Total: 542
#
# Finding Honda dealers near 32626...
# Scraped: 58
# New: 0
# Total: 542
#
# Finding Honda dealers near 32960...
# Scraped: 54
# New: 2
# Total: 544
#
# Finding Honda dealers near 33014...
# Scraped: 46
# New: 0
# Total: 544
#
# Finding Honda dealers near 33040...
# Scraped: 32
# New: 0
# Total: 544
#
# Finding Honda dealers near 33563...
# Scraped: 59
# New: 0
# Total: 544
#
# Finding Honda dealers near 35016...
# Scraped: 74
# New: 9
# Total: 553
#
# Finding Honda dealers near 35045...
# Scraped: 72
# New: 3
# Total: 556
#
# Finding Honda dealers near 36027...
# Scraped: 69
# New: 0
# Total: 556
#
# Finding Honda dealers near 36426...
# Scraped: 56
# New: 8
# Total: 564
#
# Finding Honda dealers near 37013...
# Scraped: 83
# New: 7
# Total: 571
#
# Finding Honda dealers near 38012...
# Scraped: 54
# New: 13
# Total: 584
#
# Finding Honda dealers near 38701...
# Scraped: 46
# New: 11
# Total: 595
#
# Finding Honda dealers near 38821...
# Scraped: 64
# New: 0
# Total: 595
#
# Finding Honda dealers near 39042...
# Scraped: 52
# New: 1
# Total: 596
#
# Finding Honda dealers near 39466...
# Scraped: 33
# New: 0
# Total: 596
#
# Finding Honda dealers near 40004...
# Scraped: 91
# New: 8
# Total: 604
#
# Finding Honda dealers near 41041...
# Scraped: 118
# New: 0
# Total: 604
#
# Finding Honda dealers near 42001...
# Scraped: 60
# New: 5
# Total: 609
#
# Finding Honda dealers near 43015...
# Scraped: 133
# New: 13
# Total: 622
#
# Finding Honda dealers near 43502...
# Scraped: 154
# New: 38
# Total: 660
#
# Finding Honda dealers near 46001...
# Scraped: 148
# New: 2
# Total: 662
#
# Finding Honda dealers near 46304...
# Scraped: 129
# New: 12
# Total: 674
#
# Finding Honda dealers near 47591...
# Scraped: 100
# New: 0
# Total: 674
#
# Finding Honda dealers near 48035...
# Scraped: 112
# New: 0
# Total: 674
#
# Finding Honda dealers near 48617...
# Scraped: 95
# New: 1
# Total: 675
#
# Finding Honda dealers near 49707...
# Scraped: 31
# New: 0
# Total: 675
#
# Finding Honda dealers near 49783...
# Scraped: 10
# New: 1
# Total: 676
#
# Finding Honda dealers near 49801...
# Scraped: 33
# New: 6
# Total: 682
#
# Finding Honda dealers near 50010...
# Scraped: 47
# New: 30
# Total: 712
#
# Finding Honda dealers near 51001...
# Scraped: 26
# New: 3
# Total: 715
#
# Finding Honda dealers near 51501...
# Scraped: 30
# New: 3
# Total: 718
#
# Finding Honda dealers near 52001...
# Scraped: 84
# New: 0
# Total: 718
#
# Finding Honda dealers near 52556...
# Scraped: 84
# New: 0
# Total: 718
#
# Finding Honda dealers near 53012...
# Scraped: 92
# New: 0
# Total: 718
#
# Finding Honda dealers near 54001...
# Scraped: 34
# New: 3
# Total: 721
#
# Finding Honda dealers near 54401...
# Scraped: 70
# New: 0
# Total: 721
#
# Finding Honda dealers near 54806...
# Scraped: 25
# New: 0
# Total: 721
#
# Finding Honda dealers near 55342...
# Scraped: 30
# New: 1
# Total: 722
#
# Finding Honda dealers near 55723...
# Scraped: 17
# New: 0
# Total: 722
#
# Finding Honda dealers near 55912...
# Scraped: 44
# New: 0
# Total: 722
#
# Finding Honda dealers near 56425...
# Scraped: 24
# New: 0
# Total: 722
#
# Finding Honda dealers near 56510...
# Scraped: 17
# New: 2
# Total: 724
#
# Finding Honda dealers near 56763...
# Scraped: 6
# New: 0
# Total: 724
#
# Finding Honda dealers near 57006...
# Scraped: 26
# New: 0
# Total: 724
#
# Finding Honda dealers near 57362...
# Scraped: 8
# New: 2
# Total: 726
#
# Finding Honda dealers near 57702...
# Scraped: 8
# New: 4
# Total: 730
#
# Finding Honda dealers near 58220...
# Scraped: 7
# New: 0
# Total: 730
#
# Finding Honda dealers near 58318...
# Scraped: 6
# New: 1
# Total: 731
#
# Finding Honda dealers near 58401...
# Scraped: 10
# New: 0
# Total: 731
#
# Finding Honda dealers near 58545...
# Scraped: 8
# New: 0
# Total: 731
#
# Finding Honda dealers near 58623...
# Scraped: 7
# New: 0
# Total: 731
#
# Finding Honda dealers near 58801...
# Scraped: 4
# New: 0
# Total: 731
#
# Finding Honda dealers near 59011...
# Scraped: 9
# New: 8
# Total: 739
#
# Finding Honda dealers near 59034...
# Scraped: 9
# New: 0
# Total: 739
#
# Finding Honda dealers near 59230...
# Scraped: 6
# New: 0
# Total: 739
#
# Finding Honda dealers near 59405...
# Scraped: 7
# New: 1
# Total: 740
#
# Finding Honda dealers near 59427...
# Scraped: 9
# New: 3
# Total: 743
#
# Finding Honda dealers near 59501...
# Scraped: 7
# New: 0
# Total: 743
#
# Finding Honda dealers near 59701...
# Scraped: 12
# New: 2
# Total: 745
#
# Finding Honda dealers near 59864...
# Scraped: 12
# New: 2
# Total: 747
#
# Finding Honda dealers near 61342...
# Scraped: 99
# New: 0
# Total: 747
#
# Finding Honda dealers near 61822...
# Scraped: 112
# New: 0
# Total: 747
#
# Finding Honda dealers near 62033...
# Scraped: 81
# New: 0
# Total: 747
#
# Finding Honda dealers near 63935...
# Scraped: 43
# New: 3
# Total: 750
#
# Finding Honda dealers near 64014...
# Scraped: 43
# New: 6
# Total: 756
#
# Finding Honda dealers near 64804...
# Scraped: 44
# New: 8
# Total: 764
#
# Finding Honda dealers near 65020...
# Scraped: 42
# New: 0
# Total: 764
#
# Finding Honda dealers near 66427...
# Scraped: 31
# New: 1
# Total: 765
#
# Finding Honda dealers near 67010...
# Scraped: 36
# New: 2
# Total: 767
#
# Finding Honda dealers near 67054...
# Scraped: 21
# New: 1
# Total: 768
#
# Finding Honda dealers near 67473...
# Scraped: 26
# New: 0
# Total: 768
#
# Finding Honda dealers near 67735...
# Scraped: 20
# New: 12
# Total: 780
#
# Finding Honda dealers near 67951...
# Scraped: 17
# New: 1
# Total: 781
#
# Finding Honda dealers near 68763...
# Scraped: 10
# New: 0
# Total: 781
#
# Finding Honda dealers near 68803...
# Scraped: 23
# New: 0
# Total: 781
#
# Finding Honda dealers near 69022...
# Scraped: 15
# New: 0
# Total: 781
#
# Finding Honda dealers near 69145...
# Scraped: 19
# New: 1
# Total: 782
#
# Finding Honda dealers near 70342...
# Scraped: 36
# New: 8
# Total: 790
#
# Finding Honda dealers near 70607...
# Scraped: 48
# New: 13
# Total: 803
#
# Finding Honda dealers near 71040...
# Scraped: 58
# New: 14
# Total: 817
#
# Finding Honda dealers near 71334...
# Scraped: 44
# New: 0
# Total: 817
#
# Finding Honda dealers near 71832...
# Scraped: 52
# New: 4
# Total: 821
#
# Finding Honda dealers near 72019...
# Scraped: 37
# New: 0
# Total: 821
#
# Finding Honda dealers near 73010...
# Scraped: 42
# New: 1
# Total: 822
#
# Finding Honda dealers near 73644...
# Scraped: 37
# New: 1
# Total: 823
#
# Finding Honda dealers near 74063...
# Scraped: 51
# New: 0
# Total: 823
#
# Finding Honda dealers near 75006...
# Scraped: 60
# New: 7
# Total: 830
#
# Finding Honda dealers near 75605...
# Scraped: 66
# New: 0
# Total: 830
#
# Finding Honda dealers near 75939...
# Scraped: 62
# New: 3
# Total: 833
#
# Finding Honda dealers near 76424...
# Scraped: 44
# New: 3
# Total: 836
#
# Finding Honda dealers near 76502...
# Scraped: 58
# New: 2
# Total: 838
#
# Finding Honda dealers near 76825...
# Scraped: 48
# New: 1
# Total: 839
#
# Finding Honda dealers near 76932...
# Scraped: 18
# New: 1
# Total: 840
#
# Finding Honda dealers near 77058...
# Scraped: 49
# New: 0
# Total: 840
#
# Finding Honda dealers near 77901...
# Scraped: 37
# New: 2
# Total: 842
#
# Finding Honda dealers near 78009...
# Scraped: 38
# New: 0
# Total: 842
#
# Finding Honda dealers near 78041...
# Scraped: 15
# New: 0
# Total: 842
#
# Finding Honda dealers near 78501...
# Scraped: 12
# New: 0
# Total: 842
#
# Finding Honda dealers near 78840...
# Scraped: 18
# New: 0
# Total: 842
#
# Finding Honda dealers near 79007...
# Scraped: 14
# New: 0
# Total: 842
#
# Finding Honda dealers near 79072...
# Scraped: 12
# New: 0
# Total: 842
#
# Finding Honda dealers near 79323...
# Scraped: 12
# New: 4
# Total: 846
#
# Finding Honda dealers near 79549...
# Scraped: 28
# New: 0
# Total: 846
#
# Finding Honda dealers near 79772...
# Scraped: 11
# New: 0
# Total: 846
#
# Finding Honda dealers near 79925...
# Scraped: 9
# New: 3
# Total: 849
#
# Finding Honda dealers near 80011...
# Scraped: 20
# New: 1
# Total: 850
#
# Finding Honda dealers near 81050...
# Scraped: 19
# New: 1
# Total: 851
#
# Finding Honda dealers near 81101...
# Scraped: 18
# New: 1
# Total: 852
#
# Finding Honda dealers near 81303...
# Scraped: 16
# New: 1
# Total: 853
#
# Finding Honda dealers near 81416...
# Scraped: 22
# New: 5
# Total: 858
#
# Finding Honda dealers near 81625...
# Scraped: 25
# New: 3
# Total: 861
#
# Finding Honda dealers near 82070...
# Scraped: 19
# New: 0
# Total: 861
#
# Finding Honda dealers near 82401...
# Scraped: 8
# New: 0
# Total: 861
#
# Finding Honda dealers near 82609...
# Scraped: 17
# New: 0
# Total: 861
#
# Finding Honda dealers near 82901...
# Scraped: 21
# New: 0
# Total: 861
#
# Finding Honda dealers near 83001...
# Scraped: 17
# New: 1
# Total: 862
#
# Finding Honda dealers near 83301...
# Scraped: 12
# New: 1
# Total: 863
#
# Finding Honda dealers near 83501...
# Scraped: 16
# New: 4
# Total: 867
#
# Finding Honda dealers near 83661...
# Scraped: 15
# New: 1
# Total: 868
#
# Finding Honda dealers near 83852...
# Scraped: 13
# New: 0
# Total: 868
#
# Finding Honda dealers near 84003...
# Scraped: 14
# New: 1
# Total: 869
#
# Finding Honda dealers near 84701...
# Scraped: 14
# New: 3
# Total: 872
#
# Finding Honda dealers near 84721...
# Scraped: 14
# New: 3
# Total: 875
#
# Finding Honda dealers near 85014...
# Scraped: 19
# New: 14
# Total: 889
#
# Finding Honda dealers near 85344...
# Scraped: 81
# New: 59
# Total: 948
#
# Finding Honda dealers near 85546...
# Scraped: 20
# New: 0
# Total: 948
#
# Finding Honda dealers near 85621...
# Scraped: 14
# New: 0
# Total: 948
#
# Finding Honda dealers near 85901...
# Scraped: 20
# New: 0
# Total: 948
#
# Finding Honda dealers near 86001...
# Scraped: 21
# New: 0
# Total: 948
#
# Finding Honda dealers near 87031...
# Scraped: 10
# New: 0
# Total: 948
#
# Finding Honda dealers near 87301...
# Scraped: 18
# New: 0
# Total: 948
#
# Finding Honda dealers near 87901...
# Scraped: 11
# New: 0
# Total: 948
#
# Finding Honda dealers near 88201...
# Scraped: 13
# New: 0
# Total: 948
#
# Finding Honda dealers near 88401...
# Scraped: 12
# New: 0
# Total: 948
#
# Finding Honda dealers near 89014...
# Scraped: 76
# New: 5
# Total: 953
#
# Finding Honda dealers near 89447...
# Scraped: 56
# New: 54
# Total: 1007
#
# Finding Honda dealers near 89801...
# Scraped: 13
# New: 0
# Total: 1007
#
# Finding Honda dealers near 90007...
# Scraped: 80
# New: 6
# Total: 1013
#
# Finding Honda dealers near 91942...
# Scraped: 71
# New: 0
# Total: 1013
#
# Finding Honda dealers near 93212...
# Scraped: 118
# New: 0
# Total: 1013
#
# Finding Honda dealers near 93427...
# Scraped: 99
# New: 0
# Total: 1013
#
# Finding Honda dealers near 93907...
# Scraped: 68
# New: 0
# Total: 1013
#
# Finding Honda dealers near 94534...
# Scraped: 60
# New: 2
# Total: 1015
#
# Finding Honda dealers near 95501...
# Scraped: 45
# New: 6
# Total: 1021
#
# Finding Honda dealers near 95928...
# Scraped: 60
# New: 0
# Total: 1021
#
# Finding Honda dealers near 96101...
# Scraped: 33
# New: 0
# Total: 1021
#
# Finding Honda dealers near 96720...
# Scraped: 6
# New: 6
# Total: 1027
#
# Finding Honda dealers near 96732...
# Scraped: 7
# New: 1
# Total: 1028
#
# Finding Honda dealers near 96766...
# Scraped: 5
# New: 0
# Total: 1028
#
# Finding Honda dealers near 97006...
# Scraped: 44
# New: 31
# Total: 1059
#
# Finding Honda dealers near 97401...
# Scraped: 37
# New: 0
# Total: 1059
#
# Finding Honda dealers near 97504...
# Scraped: 26
# New: 0
# Total: 1059
#
# Finding Honda dealers near 97741...
# Scraped: 44
# New: 0
# Total: 1059
#
# Finding Honda dealers near 97801...
# Scraped: 41
# New: 0
# Total: 1059
#
# Finding Honda dealers near 98002...
# Scraped: 41
# New: 0
# Total: 1059
#
# Finding Honda dealers near 98226...
# Scraped: 33
# New: 0
# Total: 1059
#
# Finding Honda dealers near 98837...
# Scraped: 41
# New: 0
# Total: 1059
#
# Finding Honda dealers near 98855...
# Scraped: 30
# New: 0
# Total: 1059
#
# Finding Honda dealers near 99501...
# Scraped: 1
# New: 1
# Total: 1060
#
# Finding Honda dealers near 99701...
# Scraped: 1
# New: 1
# Total: 1061
#
# Finding Honda dealers near 99801...
# Scraped: 1
# New: 1
# Total: 1062

# %%
for res in results_list:
    d = {}
    d['brand'] = 'Honda'
    d['name'] = res['Name']
    d['address'] = res['Address']
    d['city'] = res['City']
    d['state'] = res['State']
    d['zip'] = res['ZipCode']
    d['phone'] =res['Phone']
    d['url'] = res['WebAddress']
    d['lat'] = res['Latitude']
    d['lon'] = res['Longitude']
    services = []
    for svc in res['Attributes']:
        if svc['Name'] not in services:
            services.append(svc['Name'])
    d['other'] = mbtools.list_to_csv(services)
    d['site_id'] = res['DealerNumber']
    locations.append(d)

my_keys = 'brand,name,address,city,state,zip,phone,url,lat,lon,other,site_id'
mbtools.make_tsv(locations,'Honda',keys=my_keys)
